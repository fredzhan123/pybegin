# %% [markdown]
# # Markdown 介绍
#
# # Level 1 Header
#
# ## Level 2 Header
#
# ### Level 3 Header
#
# #### Level 4 Header
#
# ##### Level 5 Header

# %% [markdown]
# # HTML 语句呈现分级标题
#
# <h1> Level 1 Header </h1>
#
# <h2> Level 2 Header </h2>
#
# <h3> Level 3 Header </h3>
#
# <h4> Level 4 Header </h4>
#
# <h5> Level 5 Header </h5>

# %% [markdown]
# <font color=red> colored text red </font>
#
# *italic text*  文字倾斜;
#
# _italic text_  文字倾斜;
#
# <em>italic text</em>
#
# **bold text** 文字加粗
#
# <strong>bold text</strong>
#
# <b>bold text</b>
#
# __bold text__
#
# ```html
# <font color=red> colored text red </font>
# *italic text*  文字倾斜;
#
# _italic text_  文字倾斜;
#
# <em>italic text</em>
#
# **bold text** 文字加粗
#
# <strong>bold text</strong>
#
# <b>bold text</b>
#
# __bold text__
# ```

# %% [markdown]
# ***bold and italic text***
#
# ___bold and italic text___
#
# <strong><em>bold and italic text </em></strong>
#
# ```html
# <!-- 文字加粗倾斜 -->
# ***bold and italic text***
#
# ___bold and italic text___
#
# <strong><em>bold and italic text </em></strong>
# ```

# %% [markdown]
# ~~Scratch this~~
#
# <del>Scratch this</del>
#
# ```html
# <!-- 删除线 -->
# ~~Scratch this~~
#
# <del>Scratch this</del>
# ```

# %% [markdown]
# ---

# %% [markdown]
# ***

# %% [markdown]
# ___

# %% [markdown]
# <hr>

# %% [markdown]
# * bullet point 1
# * bullet point 2

# %% [markdown]
# - bullet point 1
# - bullet point 2

# %% [markdown]
# - bullet point 1
#     - bullet point 1.1
#         - bullet point 1.1.1
#         - bullet point 1.1.2
#     - bullet point 1.2

# %% [markdown]
# 1. bullet point
# 2. bullet point

# %% [markdown]
# <ul>
# <li> item 1</li>
# <li> itme 2</li>
# <li> itme 3</li>
# <li> itme 4</li>
# </ul>

# %% [markdown]
# <ol>
# <li> item 1 </li>
# <li> itme 2 </li>
# <li> itme 3</li>
# </ol>
