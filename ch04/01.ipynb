# %% [markdown]
# Chapter 04
#
# # Python 中三类数值

# %%
x = 9
y = -9.9
z = 8 + 8j

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(z))
# Out:
# <class 'complex'>
