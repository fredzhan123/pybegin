# %% [markdown]
# Chapter 04
#
# # 数值转换

# %%
x = 88.8
y = 8

# %%
x_to_int = int(x)
print(x_to_int)
# Out:
# 88

# %%
y_to_float = float(y)
print(y_to_float)
# Out:
# 8.0

# %%
y_to_complex = complex(y)
print(y_to_complex)
# Out:
# (8+0j)

# %%
x_to_str = str(x)
print(x_to_str)
# Out:
# 88.8
