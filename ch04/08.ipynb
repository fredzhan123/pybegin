# %% [markdown]
# Chapter 04
#
# # 常用 .format() 示例

# %%
"{:.2f}".format(3.1415926)
# Out:
# '3.14'

# %%
"{:%}".format(3.1415926) #'314.159260%'
# Out:
# '314.159260%'

# %%
"{:.2%}".format(3.1415926) #'314.159260%'
# Out:
# '314.16%'

# %%
"{:.4e}".format(3.1415926) #'3.14e+00'
# Out:
# '3.1416e+00'

# %%
"{:,.3f}".format(3.1415926*1000) #'3,141.5926'
# Out:
# '3,141.593'
